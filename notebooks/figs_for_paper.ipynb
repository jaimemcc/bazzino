# %% [markdown]
# # Example results and figures for Bazzino et al paper
#
# We used spectral clustering (see Methods for full details) to classify response profiles from both replete and deplete rats after intraoral infusions of both 10 mM and 45 mM NaCl. This unsupervised procedure identified seven distinct clusters (Fig xA). We calculated the proportion of each response profile assigned to each different condition (which revealed that...) (Fig xB)

# %% [markdown]
# Next, to examine the development of responses over time we condensed the seven clusters into two super clusters depending on whether they exhibited a sharp increase in activity at onset of the infusion. This clustering method overlapped almoist completely with the results of clustering if we constrained profiles into just two clusters (9x.x % similarity).
